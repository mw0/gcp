# %%
import numpy as np
from __future__ import absolute_import
from __future__ import print_function
np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils import np_utils
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ee0c029e8832> in <module>()
#       4 np.random.seed(1337)  # for reproducibility
#       5
# ----> 6 from keras.datasets import mnist
#       7 from keras.models import Sequential
#       8 from keras.layers.core import Dense, Dropout, Activation, Flatten
#
# ImportError: No module named keras.datasets

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# VO table import: astropy module not available
# /usr/lib64/python2.7/site-packages/pandas/rpy/__init__.py:11: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2.
# See here for a guide on how to port your code to rpy2: http://pandas.pydata.org/pandas-docs/stable/r_interface.html
#   FutureWarning)
# :0: FutureWarning: IPython widgets are experimental and may change in the future.
# Couldn't import dot_parser, loading of dot files will not be possible.
# [INFO] This trial license of GraphLab Create is assigned to trephine1@yahoo.com and will expire on October 12, 2015. Please contact trial@dato.com for licensing options or to request a free non-commercial license for personal or academic use.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-18705 - Server binary: /usr/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1442269519.log
# [INFO] GraphLab Server Version: 1.5.2
# /usr/lib64/python2.7/xml/etree/ElementTree.py:1627: DeprecationWarning: This method of XMLParser is deprecated.  Define doctype() method on the TreeBuilder target.
#   DeprecationWarning,
# /usr/lib64/python2.7/xml/etree/ElementTree.py:1627: DeprecationWarning: This method of XMLParser is deprecated.  Define doctype() method on the TreeBuilder target.
#   DeprecationWarning,
# ERROR (theano.sandbox.cuda): Failed to compile cuda_ndarray.cu: libcublas.so.7.5: cannot open shared object file: No such file or directory
# [ERROR] Failed to compile cuda_ndarray.cu: libcublas.so.7.5: cannot open shared object file: No such file or directory
# ANSI                collections         macpath             search10
# Avogadro            colorama            macurl2path         search2
# BaseHTMLProcessor   colorize            mailbox             search3
# BaseHTTPServer      colorsys            mailcap             search4
# Bastion             commands            makerealworddoc     search5
# BeautifulSoup       compileall          markdown            search6
# CDROM               compiler            markupbase          search7
# CGIHTTPServer       concurrent          markupsafe          search8
# CORBA               contextlib          marshal             search9
# Canvas              cookielib           math                select
# ConfigParser        copy                matplotlib          selenium
# Cookie              copy_reg            md5                 selinux
# Crypto              copytildone         mechanize           semanage
# Cython              count1              meh                 seobject
# DLFCN               count2              memory_profiler     sepolgen
# Dialog              count3              mhlib               sepolicy
# DocXMLRPCServer     courseradownloader  mimetools           sequence
# FSM                 coverage            mimetypes           serial
# FileDialog          crypt               mimify              service_identity
# FixTk               cssselect           minipsutil          setroubleshoot
# HTMLParser          cssutils            mistune             sets
# IN                  csv                 mixpanel            setuptools
# IPy                 ctypes              mmap                sgmllib
# IPython             cupsext             mock                sha
# MimeWriter          curl                modulefinder        shelve
# MobiBase            curl1               multifile           shlex
# MobiCorr            curl2               multipledispatch    shutil
# MobiCorrExample     curl3               multiprocessing     signal
# MobiGrid            curses              mutex               signalSmooth
# MobiLabExample      curtsies            mwclient            simpleCorr
# MySQLdb             cv                  netCDF4             simplejson
# NaiveBayes          cv2                 netCDF4_utils       sip
# ORBit               cython              netcdftime          sipconfig
# OpenSSL             cythonmagic         netifaces           sipdistutils
# PAM                 datashape           netrc               site
# PIL                 datetime            networkx            six
# PortableServer      dateutil            new                 sklearn
# PyQt4               db1                 nfstest             slip
# PyQt5               db2                 nfstest_config      smooth
# Queue               dbhash              nis                 smtpd
# SSSDConfig          dbm                 nltk                smtplib
# ScrolledText        dbus                nntplib             snack
# SimpleDialog        decimal             nose                sndhdr
# SimpleHTTPServer    decorator           nss                 snowballstemmer
# SimpleXMLRPCServer  devassistant        ntpath              socket
# SocketServer        di                  ntplib              socket1
# StringIO            dialect             nturl2path          socket2
# TYPES               difflib             numba               sos
# Tix                 dircache            numbers             soundex
# Tkconstants         dis                 numexpr             soundextest
# Tkdnd               distutils           numpy               spamave
# Tkinter             dl                  oauth2              spambayes
# UserDict            dmidecode           odbchelper          sphinx
# UserList            dmidecodemod        odbchelpertest      sphinx_rtd_theme
# UserString          dnf                 odf                 splitStarling
# _LWPCookieJar       dnfpluginscore      opcode              spwd
# _MozillaCookieJar   dns                 open                sqlalchemy
# __builtin__         doctest             openanything        sqlite3
# __future__          docutils            operator            sqlitecachec
# __version__         dot_parser          optparse            sre
# _abcoll             drv_libxml2         os                  sre_compile
# _ast                dsextras            os2emxpath          sre_constants
# _audit              dumbdbm             ossaudiodev         sre_parse
# _bisect             dummy_thread        packet              sseclient
# _blueman            dummy_threading     pals                ssl
# _bsddb              dummyserver         pandas              starlingUtils
# _codecs             easy_install        pango               stat
# _codecs_cn          egg                 pangocairo          statsmodels
# _codecs_hk          email               parallelmagic       statsout
# _codecs_iso2022     emd                 parsephone          statvfs
# _codecs_jp          encodings           parser              storemagic
# _codecs_kr          encutils            parted              string
# _codecs_tw          errno               patsy               stringold
# _collections        exampleTestClass    pay                 stringprep
# _crypt              exceptions          pay2                strop
# _csv                fahren              pay3                struct
# _ctypes             fcntl               pcardext            subprocess
# _curses             fdpexpect           pdb                 sunau
# _curses_panel       feedparser          pdfshuffler         sunaudio
# _dbus_bindings      fetchAllSensorDat   pexpect             symbol
# _dbus_glib_bindings fibonacci           pickle              sympyprinting
# _elementtree        filecmp             pickletools         symtable
# _functools          fileinfo            piglatin            syncInds2Loc
# _gamin              fileinfo_fromdict   pip                 sys
# _hashlib            fileinput           pipes               sysconfig
# _heapq              firewall            pkg_resources       syslog
# _hotshot            flask               pkgutil             systemd
# _hsi                flask_cors          platform            tables
# _io                 flask_restful       plistlib            tabnanny
# _json               fnmatch             pltUtils            talloc
# _locale             formatstr           plural              tarfile
# _lsprof             formatter           pluraltest          telnetlib
# _markerlib          fpformat            policycoreutils     tempfile
# _multibytecodec     fractions           popen2              terminado
# _multiprocessing    fsimage             poplib              termios
# _mysql              ftplib              poppler             test
# _mysql_exceptions   fullpath            posix               test_characteristic
# _osx_support        functools           posixfile           tests
# _ped                future_builtins     posixpath           textwrap
# _psutil_linux       gamin               pprint              theano
# _psutil_posix       gc                  prettytable         this
# _pyio               gconf               problem             thread
# _pyo                gdbm                processCoordinatedRoutes threading
# _pytest             genericpath         processStarlingGridRoutes time
# _random             genshi              profile             timeit
# _semanage           geopy               progress            timing
# _snack              getopt              pstats              tkColorChooser
# _socket             getpass             psutil              tkCommonDialog
# _sqlite3            gettext             pty                 tkFileDialog
# _sqlitecache        gevent              ptyprocess          tkFont
# _sre                geventwebsocket     pwd                 tkMessageBox
# _ssl                gi                  pwquality           tkSimpleDialog
# _strptime           gio                 pxssh               toaiff
# _struct             github              py                  token
# _symtable           glib                pyPdf               tokenize
# _sysconfigdata      glob                py_compile          toolz
# _threading_local    gluster             pyanaconda          tornado
# _tkinter            gnome               pyasn1              trace
# _warnings           gnome_abrt          pyasn1_modules      traceback
# _weakref            gnomecanvas         pyatspi             ttk
# _weakrefset         gnomevfs            pyclbr              tty
# _yaml               gobject             pycryptsetup        turtle
# abc                 google_translate_api pycurl              twdump
# abrt_exception_handler gpgme               pydoc               twfriends
# acutil              gps                 pydoc_data          twisted
# aifc                grade               pydot               twitter1
# alabaster           graphlab            pyexpat             twitter2
# alsaaudio           graphlab_util       pyfontify           twitter3
# aniso8601           greenlet            pyfros              twitter4
# antigravity         greet               pygeocoder          twjoin
# anydbm              grep                pygeolib            twspider
# apihelper           gridfs              pygments            txtcheck
# apihelpertest       grp                 pygtk               txtcheck2
# apsw                grub                pygtkcompat         txtcheck3
# argecho             gtk                 pyinotify           txtcount
# argfile             gtkunixprint        pykickstart         txtdelete
# argparse            gtweak              pylab               txtmd5
# argtest             guihelpers          pymongo             txtsize
# array               gyp                 pynotify            types
# ast                 gzip                pyo                 uc2
# asynchat            handyTime           pyolib              unicode2koi8r
# asyncore            hashlib             pyparsing           unicodedata
# atexit              hawkey              pypro               unittest
# atk                 heapq               pyproj              urlforever
# audiodev            hmac                pysss               urlgrabber
# audioop             hotshot             pysss_murmur        urllib
# audit               hpi                 pystache            urllib1
# augeas              hpmudext            pytest              urllib2
# auparse             hsi                 pytz                urllib3
# autoreload          html5lib            pyxb                urllink2
# autosize            htmlentitydefs      pyximport           urllinks
# avelist             htmllib             quopri              urllister
# avenum              httplib             random              urlparse
# average             httplib2            re                  urlregex
# awscli              httpretty           re01                urlwords
# babel               humanize            re02                urwid
# backports           idlelib             re03                user
# base64              idna                re04                uu
# baseobj             ihooks              re05                uuid
# bcdoc               imageop             re06                veusz
# bdb                 imaplib             re07                virtualenv
# binascii            imghdr              re08                virtualenv_support
# binhex              imp                 re09                warnings
# bisect              importlib           re10                wave
# blaze               imputil             re11                weakref
# blessings           iniparse            re12                webbrowser
# blivet              init_calibre        re13                websocket
# block               initial_setup       re14                weightedStats
# blueman             inspect             readPlotData        werkzeug
# bokeh               into                readline            wesnoth
# bonobo              io                  regression          whichdb
# boto                itertools           report              wikigrade
# botocore            itsdangerous        reportclient        windowedAvg
# bottleneck          javapackages        reportlab           wordlist
# bpdb                jinja2              repr                words
# bpython             jmespath            requests            wsave
# bs4                 js2c                resource            wsgiref
# bsddb               jsmin               rexec               wx
# bson                json                rfc822              wxPython
# builddialectexamples jsonschema          rlcompleter         wxversion
# butterworthBandPass keyword             rmagic              xattr
# bz2                 kgptest             rmc                 xcb
# cPickle             kitchen             rml                 xdg
# cProfile            langtable           robotparser         xdrlib
# cStringIO           largest             rollingAvg          xen
# cairo               lib2to3             roman               xml
# calendar            libcomps            romantest           xml1
# caribou             libiscsi            rosetta             xml2
# celsius             liblzma             rpm                 xmllib
# certifi             librato             rpmUtils            xmlrpclib
# cgi                 librepo             rsa                 xxsubtype
# cgitb               libuser             run                 yaml
# characteristic      libxml2             runpy               youtube_dl
# chardet             libxml2mod          savitzkyGolay       yum
# cherrypy            linecache           scanext             yumexbackend
# chunk               linuxaudiodev       sched               yumexbase
# click               liveusb             scipy               yumexgui
# cmath               locale              screen              yumutils
# cmd                 lockfile            scservices          zipfile
# code                logging             seaborn             zipimport
# codecs              lxml                search              zlib
# codeop              lzma                search1             zmq
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose descriptions contain the word "spam".
